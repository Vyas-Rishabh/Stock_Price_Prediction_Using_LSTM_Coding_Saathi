# %% [markdown]
# # Stock Price Prediction Using LSTM

# %% [markdown]
# ### Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("Stocks_dataset.csv")
df.head()
# Out:
#   symbol                       date   close    high       low    open  \
# 0   GOOG  2016-06-14 00:00:00+00:00  718.27  722.47  713.1200  716.48
# 1   GOOG  2016-06-15 00:00:00+00:00  718.92  722.98  717.3100  719.00
# 2   GOOG  2016-06-16 00:00:00+00:00  710.36  716.65  703.2600  714.91
# 3   GOOG  2016-06-17 00:00:00+00:00  691.72  708.82  688.4515  708.65
# 4   GOOG  2016-06-20 00:00:00+00:00  693.71  702.48  693.4100  698.77
#
#     volume  adjClose  adjHigh    adjLow  adjOpen  adjVolume  divCash  \
# 0  1306065    718.27   722.47  713.1200   716.48    1306065      0.0
# 1  1214517    718.92   722.98  717.3100   719.00    1214517      0.0
# 2  1982471    710.36   716.65  703.2600   714.91    1982471      0.0
# 3  3402357    691.72   708.82  688.4515   708.65    3402357      0.0
# 4  2082538    693.71   702.48  693.4100   698.77    2082538      0.0
#
#    splitFactor
# 0          1.0
# 1          1.0
# 2          1.0
# 3          1.0
# 4          1.0

# %%
#Shape of Data
df.shape
# Out:
# (1258, 14)

# %%
#Statistical Descritpion
df.describe()
# Out:
#              close         high          low         open        volume  \
# count  1258.000000  1258.000000  1258.000000  1258.000000  1.258000e+03
# mean   1216.317067  1227.430934  1204.176430  1215.260779  1.601590e+06
# std     383.333358   387.570872   378.777094   382.446995  6.960172e+05
# min     668.260000   672.300000   663.284000   671.000000  3.467530e+05
# 25%     960.802500   968.757500   952.182500   959.005000  1.173522e+06
# 50%    1132.460000  1143.935000  1117.915000  1131.150000  1.412588e+06
# 75%    1360.595000  1374.345000  1348.557500  1361.075000  1.812156e+06
# max    2521.600000  2526.990000  2498.290000  2524.920000  6.207027e+06
#
#           adjClose      adjHigh       adjLow      adjOpen     adjVolume  \
# count  1258.000000  1258.000000  1258.000000  1258.000000  1.258000e+03
# mean   1216.317067  1227.430936  1204.176436  1215.260779  1.601590e+06
# std     383.333358   387.570873   378.777099   382.446995  6.960172e+05
# min     668.260000   672.300000   663.284000   671.000000  3.467530e+05
# 25%     960.802500   968.757500   952.182500   959.005000  1.173522e+06
# 50%    1132.460000  1143.935000  1117.915000  1131.150000  1.412588e+06
# 75%    1360.595000  1374.345000  1348.557500  1361.075000  1.812156e+06
# max    2521.600000  2526.990000  2498.290000  2524.920000  6.207027e+06
#
#        divCash  splitFactor
# count   1258.0       1258.0
# mean       0.0          1.0
# std        0.0          0.0
# min        0.0          1.0
# 25%        0.0          1.0
# 50%        0.0          1.0
# 75%        0.0          1.0
# max        0.0          1.0

# %%
#Data Summary
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1258 entries, 0 to 1257
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   symbol       1258 non-null   object
#  1   date         1258 non-null   object
#  2   close        1258 non-null   float64
#  3   high         1258 non-null   float64
#  4   low          1258 non-null   float64
#  5   open         1258 non-null   float64
#  6   volume       1258 non-null   int64
#  7   adjClose     1258 non-null   float64
#  8   adjHigh      1258 non-null   float64
#  9   adjLow       1258 non-null   float64
#  10  adjOpen      1258 non-null   float64
#  11  adjVolume    1258 non-null   int64
#  12  divCash      1258 non-null   float64
#  13  splitFactor  1258 non-null   float64
# dtypes: float64(10), int64(2), object(2)
# memory usage: 137.7+ KB

# %%
#Check Null values
df.isnull().sum()
# Out:
# symbol         0
# date           0
# close          0
# high           0
# low            0
# open           0
# volume         0
# adjClose       0
# adjHigh        0
# adjLow         0
# adjOpen        0
# adjVolume      0
# divCash        0
# splitFactor    0
# dtype: int64

# %%
#No null values in data
df = df[['date','open','close']] #Require columns extracting
df['date'] = pd.to_datetime(df['date'].apply(lambda x: x.split()[0])) #Convert to datetime dtype
df.set_index('date', drop=True, inplace=True)
df.head()
# Out:
#               open   close
# date
# 2016-06-14  716.48  718.27
# 2016-06-15  719.00  718.92
# 2016-06-16  714.91  710.36
# 2016-06-17  708.65  691.72
# 2016-06-20  698.77  693.71

# %%
# Now we plotting open and closing price on date index
fig, ax = plt.subplots(1,2, figsize=(20,7))
ax[0].plot(df['open'], label = 'open', color = 'green')
ax[0].set_xlabel('Data', size=13)
ax[0].set_ylabel('Price', size=13)
ax[0].legend()

ax[1].plot(df['close'], label = 'Close', color = 'red')
ax[1].set_xlabel('Data', size=13)
ax[1].set_ylabel('Price', size=13)
ax[1].legend()

# %% [markdown]
# ### Data Preprocessing

# %%
# we'll normalizing all the values of all columns using MinMaxScaler
from sklearn.preprocessing import MinMaxScaler
mms = MinMaxScaler()
df[df.columns] = mms.fit_transform(df)
df.head()
# Out:
#                 open     close
# date
# 2016-06-14  0.024532  0.026984
# 2016-06-15  0.025891  0.027334
# 2016-06-16  0.023685  0.022716
# 2016-06-17  0.020308  0.012658
# 2016-06-20  0.014979  0.013732

# %%
#split data into Training and testing
training_size = round(len(df) * 0.75) #75% for training
training_size
# Out:
# 944

# %%
training_data = df[:training_size]
testing_data = df[training_size:]
training_data.shape, testing_data.shape
# Out:
# ((944, 2), (314, 2))

# %%
# we'll create sequence of data for training and testing

def create_sequence(dataset):
    sequence = []
    labels = []
    
    start_idx = 0
    
    for stop_idx in range(50, len(dataset)): #selecting 50 rows at a time
        sequence.append(dataset.iloc[start_idx:stop_idx])
        labels.append(dataset.iloc[stop_idx])
        start_idx += 1
    return (np.array(sequence), np.array(labels))

# %%
train_seq, train_label, = create_sequence(training_data)
test_seq, test_label = create_sequence(testing_data)
train_seq.shape, train_label.shape, test_seq.shape, test_label.shape
# Out:
# ((894, 50, 2), (894, 2), (264, 50, 2), (264, 2))

# %% [markdown]
# ### Create LSTM Model

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, Bidirectional

# %%
#import Sequential from keras.models
model = Sequential()
#import Dense, Dropout, LSTM, Bidirectional from keras.layers
model.add(LSTM(units=50, return_sequences=True, input_shape=(train_seq.shape[1], train_seq.shape[2])))

model.add(Dropout(0.1))
model.add(LSTM(units=50))

model.add(Dense(2))

model.compile(loss = 'mean_squared_error', optimizer = 'adam', metrics = ['mean_absolute_error'])

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 50, 50)            10600
#
#  dropout (Dropout)           (None, 50, 50)            0
#
#  lstm_1 (LSTM)               (None, 50)                20200
#
#  dense (Dense)               (None, 2)                 102
#
# =================================================================
# Total params: 30902 (120.71 KB)
# Trainable params: 30902 (120.71 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# fitting the model by iterating the dataset over 100 times(100 epochs)
model.fit(train_seq, train_label, epochs = 100, validation_data = (test_seq, test_label), verbose = 1)
# Out:
# Epoch 1/100
# 28/28 [==============================] - 4s 46ms/step - loss: 0.0082 - mean_absolute_error: 0.0618 - val_loss: 0.0116 - val_mean_absolute_error: 0.0830
# Epoch 2/100
# 28/28 [==============================] - 1s 21ms/step - loss: 7.3860e-04 - mean_absolute_error: 0.0216 - val_loss: 0.0037 - val_mean_absolute_error: 0.0466
# Epoch 3/100
# 28/28 [==============================] - 1s 22ms/step - loss: 4.4218e-04 - mean_absolute_error: 0.0155 - val_loss: 0.0027 - val_mean_absolute_error: 0.0403
# Epoch 4/100
# 28/28 [==============================] - 1s 22ms/step - loss: 4.5139e-04 - mean_absolute_error: 0.0154 - val_loss: 0.0033 - val_mean_absolute_error: 0.0446
# Epoch 5/100
# 28/28 [==============================] - 1s 22ms/step - loss: 4.2917e-04 - mean_absolute_error: 0.0151 - val_loss: 0.0032 - val_mean_absolute_error: 0.0439
# Epoch 6/100
# 28/28 [==============================] - 1s 22ms/step - loss: 4.1802e-04 - mean_absolute_error: 0.0150 - val_loss: 0.0034 - val_mean_absolute_error: 0.0449
# Epoch 7/100
# 28/28 [==============================] - 1s 22ms/step - loss: 4.0603e-04 - mean_absolute_error: 0.0145 - val_loss: 0.0026 - val_mean_absolute_error: 0.0383
# Epoch 8/100
# 28/28 [==============================] - 1s 22ms/step - loss: 3.9476e-04 - mean_absolute_error: 0.0146 - val_loss: 0.0026 - val_mean_absolute_error: 0.0384
# Epoch 9/100
# 28/28 [==============================] - 1s 22ms/step - loss: 4.1629e-04 - mean_absolute_error: 0.0149 - val_loss: 0.0045 - val_mean_absolute_error: 0.0544
# Epoch 10/100
# 28/28 [==============================] - 1s 21ms/step - loss: 4.0475e-04 - mean_absolute_error: 0.0148 - val_loss: 0.0040 - val_mean_absolute_error: 0.0504
# Epoch 11/100
# 28/28 [==============================] - 1s 22ms/step - loss: 3.5374e-04 - mean_absolute_error: 0.0136 - val_loss: 0.0032 - val_mean_absolute_error: 0.0439
# Epoch 12/100
# 28/28 [==============================] - 1s 22ms/step - loss: 3.6521e-04 - mean_absolute_error: 0.0140 - val_loss: 0.0033 - val_mean_absolute_error: 0.0452
# Epoch 13/100
# 28/28 [==============================] - 1s 21ms/step - loss: 3.3011e-04 - mean_absolute_error: 0.0133 - val_loss: 0.0024 - val_mean_absolute_error: 0.0381
# Epoch 14/100
# 28/28 [==============================] - 1s 21ms/step - loss: 3.3961e-04 - mean_absolute_error: 0.0136 - val_loss: 0.0020 - val_mean_absolute_error: 0.0333
# Epoch 15/100
# 28/28 [==============================] - 1s 21ms/step - loss: 3.2324e-04 - mean_absolute_error: 0.0133 - val_loss: 0.0025 - val_mean_absolute_error: 0.0395
# Epoch 16/100
# 28/28 [==============================] - 1s 22ms/step - loss: 3.2177e-04 - mean_absolute_error: 0.0131 - val_loss: 0.0050 - val_mean_absolute_error: 0.0585
# Epoch 17/100
# 28/28 [==============================] - 1s 22ms/step - loss: 3.1393e-04 - mean_absolute_error: 0.0132 - val_loss: 0.0026 - val_mean_absolute_error: 0.0392
# Epoch 18/100
# 28/28 [==============================] - 1s 28ms/step - loss: 3.0661e-04 - mean_absolute_error: 0.0127 - val_loss: 0.0030 - val_mean_absolute_error: 0.0431
# Epoch 19/100
# 28/28 [==============================] - 1s 23ms/step - loss: 3.0002e-04 - mean_absolute_error: 0.0126 - val_loss: 0.0048 - val_mean_absolute_error: 0.0563
# Epoch 20/100
# 28/28 [==============================] - 1s 24ms/step - loss: 2.6887e-04 - mean_absolute_error: 0.0121 - val_loss: 0.0038 - val_mean_absolute_error: 0.0486
# Epoch 21/100
# 28/28 [==============================] - 1s 23ms/step - loss: 2.8070e-04 - mean_absolute_error: 0.0122 - val_loss: 0.0042 - val_mean_absolute_error: 0.0523
# Epoch 22/100
# 28/28 [==============================] - 1s 22ms/step - loss: 2.8240e-04 - mean_absolute_error: 0.0126 - val_loss: 0.0011 - val_mean_absolute_error: 0.0251
# Epoch 23/100
# 28/28 [==============================] - 1s 22ms/step - loss: 3.0620e-04 - mean_absolute_error: 0.0129 - val_loss: 0.0045 - val_mean_absolute_error: 0.0539
# Epoch 24/100
# 28/28 [==============================] - 1s 22ms/step - loss: 2.7558e-04 - mean_absolute_error: 0.0122 - val_loss: 0.0029 - val_mean_absolute_error: 0.0416
# Epoch 25/100
# 28/28 [==============================] - 1s 22ms/step - loss: 2.7037e-04 - mean_absolute_error: 0.0118 - val_loss: 0.0037 - val_mean_absolute_error: 0.0482
# Epoch 26/100
# 28/28 [==============================] - 1s 22ms/step - loss: 2.5274e-04 - mean_absolute_error: 0.0115 - val_loss: 0.0044 - val_mean_absolute_error: 0.0523
# Epoch 27/100
# 28/28 [==============================] - 1s 22ms/step - loss: 2.4851e-04 - mean_absolute_error: 0.0117 - val_loss: 0.0050 - val_mean_absolute_error: 0.0558
# Epoch 28/100
# 28/28 [==============================] - 1s 22ms/step - loss: 2.4161e-04 - mean_absolute_error: 0.0114 - val_loss: 0.0030 - val_mean_absolute_error: 0.0423
# Epoch 29/100
# 28/28 [==============================] - 1s 22ms/step - loss: 2.5390e-04 - mean_absolute_error: 0.0118 - val_loss: 0.0029 - val_mean_absolute_error: 0.0409
# Epoch 30/100
# 28/28 [==============================] - 1s 22ms/step - loss: 2.4857e-04 - mean_absolute_error: 0.0116 - val_loss: 0.0027 - val_mean_absolute_error: 0.0385
# Epoch 31/100
# 28/28 [==============================] - 1s 22ms/step - loss: 2.3760e-04 - mean_absolute_error: 0.0112 - val_loss: 0.0046 - val_mean_absolute_error: 0.0536
# Epoch 32/100
# 28/28 [==============================] - 1s 22ms/step - loss: 2.4260e-04 - mean_absolute_error: 0.0116 - val_loss: 0.0067 - val_mean_absolute_error: 0.0673
# Epoch 33/100
# 28/28 [==============================] - 1s 22ms/step - loss: 2.2662e-04 - mean_absolute_error: 0.0110 - val_loss: 0.0061 - val_mean_absolute_error: 0.0634
# Epoch 34/100
# 28/28 [==============================] - 1s 22ms/step - loss: 2.1867e-04 - mean_absolute_error: 0.0108 - val_loss: 0.0050 - val_mean_absolute_error: 0.0567
# Epoch 35/100
# 28/28 [==============================] - 1s 22ms/step - loss: 2.3334e-04 - mean_absolute_error: 0.0112 - val_loss: 0.0063 - val_mean_absolute_error: 0.0640
# Epoch 36/100
# 28/28 [==============================] - 1s 22ms/step - loss: 2.2837e-04 - mean_absolute_error: 0.0113 - val_loss: 0.0032 - val_mean_absolute_error: 0.0433
# Epoch 37/100
# 28/28 [==============================] - 1s 22ms/step - loss: 2.1923e-04 - mean_absolute_error: 0.0108 - val_loss: 0.0066 - val_mean_absolute_error: 0.0667
# Epoch 38/100
# 28/28 [==============================] - 1s 22ms/step - loss: 2.1248e-04 - mean_absolute_error: 0.0108 - val_loss: 0.0038 - val_mean_absolute_error: 0.0478
# Epoch 39/100
# 28/28 [==============================] - 1s 22ms/step - loss: 2.2130e-04 - mean_absolute_error: 0.0108 - val_loss: 0.0030 - val_mean_absolute_error: 0.0418
# Epoch 40/100
# 28/28 [==============================] - 1s 22ms/step - loss: 1.9098e-04 - mean_absolute_error: 0.0102 - val_loss: 0.0043 - val_mean_absolute_error: 0.0510
# Epoch 41/100
# 28/28 [==============================] - 1s 22ms/step - loss: 1.9048e-04 - mean_absolute_error: 0.0101 - val_loss: 0.0030 - val_mean_absolute_error: 0.0407
# Epoch 42/100
# 28/28 [==============================] - 1s 22ms/step - loss: 2.0804e-04 - mean_absolute_error: 0.0105 - val_loss: 0.0061 - val_mean_absolute_error: 0.0623
# Epoch 43/100
# 28/28 [==============================] - 1s 22ms/step - loss: 2.0756e-04 - mean_absolute_error: 0.0105 - val_loss: 0.0043 - val_mean_absolute_error: 0.0511
# Epoch 44/100
# 28/28 [==============================] - 1s 22ms/step - loss: 1.9905e-04 - mean_absolute_error: 0.0103 - val_loss: 0.0038 - val_mean_absolute_error: 0.0467
# Epoch 45/100
# 28/28 [==============================] - 1s 23ms/step - loss: 2.0412e-04 - mean_absolute_error: 0.0104 - val_loss: 0.0047 - val_mean_absolute_error: 0.0547
# Epoch 46/100
# 28/28 [==============================] - 1s 23ms/step - loss: 1.9355e-04 - mean_absolute_error: 0.0101 - val_loss: 0.0027 - val_mean_absolute_error: 0.0387
# Epoch 47/100
# 28/28 [==============================] - 1s 22ms/step - loss: 2.2969e-04 - mean_absolute_error: 0.0113 - val_loss: 0.0032 - val_mean_absolute_error: 0.0428
# Epoch 48/100
# 28/28 [==============================] - 1s 22ms/step - loss: 1.7965e-04 - mean_absolute_error: 0.0098 - val_loss: 0.0031 - val_mean_absolute_error: 0.0409
# Epoch 49/100
# 28/28 [==============================] - 1s 22ms/step - loss: 2.1088e-04 - mean_absolute_error: 0.0108 - val_loss: 0.0032 - val_mean_absolute_error: 0.0431
# Epoch 50/100
# 28/28 [==============================] - 1s 23ms/step - loss: 1.8392e-04 - mean_absolute_error: 0.0099 - val_loss: 0.0038 - val_mean_absolute_error: 0.0480
# Epoch 51/100
# 28/28 [==============================] - 1s 22ms/step - loss: 1.8585e-04 - mean_absolute_error: 0.0101 - val_loss: 0.0024 - val_mean_absolute_error: 0.0358
# Epoch 52/100
# 28/28 [==============================] - 1s 22ms/step - loss: 1.8224e-04 - mean_absolute_error: 0.0100 - val_loss: 0.0054 - val_mean_absolute_error: 0.0596
# Epoch 53/100
# 28/28 [==============================] - 1s 22ms/step - loss: 1.7741e-04 - mean_absolute_error: 0.0096 - val_loss: 0.0050 - val_mean_absolute_error: 0.0570
# Epoch 54/100
# 28/28 [==============================] - 1s 22ms/step - loss: 1.7178e-04 - mean_absolute_error: 0.0095 - val_loss: 0.0053 - val_mean_absolute_error: 0.0592
# Epoch 55/100
# 28/28 [==============================] - 1s 22ms/step - loss: 1.6649e-04 - mean_absolute_error: 0.0095 - val_loss: 0.0033 - val_mean_absolute_error: 0.0439
# Epoch 56/100
# 28/28 [==============================] - 1s 22ms/step - loss: 1.5533e-04 - mean_absolute_error: 0.0091 - val_loss: 0.0035 - val_mean_absolute_error: 0.0451
# Epoch 57/100
# 28/28 [==============================] - 1s 22ms/step - loss: 1.7910e-04 - mean_absolute_error: 0.0097 - val_loss: 0.0061 - val_mean_absolute_error: 0.0629
# Epoch 58/100
# 28/28 [==============================] - 1s 22ms/step - loss: 1.5252e-04 - mean_absolute_error: 0.0089 - val_loss: 0.0051 - val_mean_absolute_error: 0.0564
# Epoch 59/100
# 28/28 [==============================] - 1s 22ms/step - loss: 1.6248e-04 - mean_absolute_error: 0.0094 - val_loss: 0.0036 - val_mean_absolute_error: 0.0455
# Epoch 60/100
# 28/28 [==============================] - 1s 22ms/step - loss: 1.4731e-04 - mean_absolute_error: 0.0087 - val_loss: 0.0034 - val_mean_absolute_error: 0.0439
# Epoch 61/100
# 28/28 [==============================] - 1s 22ms/step - loss: 1.3574e-04 - mean_absolute_error: 0.0083 - val_loss: 0.0045 - val_mean_absolute_error: 0.0534
# Epoch 62/100
# 28/28 [==============================] - 1s 22ms/step - loss: 1.4956e-04 - mean_absolute_error: 0.0087 - val_loss: 0.0040 - val_mean_absolute_error: 0.0486
# Epoch 63/100
# 28/28 [==============================] - 1s 22ms/step - loss: 1.4792e-04 - mean_absolute_error: 0.0090 - val_loss: 0.0038 - val_mean_absolute_error: 0.0481
# Epoch 64/100
# 28/28 [==============================] - 1s 24ms/step - loss: 1.4657e-04 - mean_absolute_error: 0.0088 - val_loss: 0.0062 - val_mean_absolute_error: 0.0643
# Epoch 65/100
# 28/28 [==============================] - 1s 23ms/step - loss: 1.4961e-04 - mean_absolute_error: 0.0090 - val_loss: 0.0052 - val_mean_absolute_error: 0.0580
# Epoch 66/100
# 28/28 [==============================] - 1s 22ms/step - loss: 1.4375e-04 - mean_absolute_error: 0.0088 - val_loss: 0.0035 - val_mean_absolute_error: 0.0463
# Epoch 67/100
# 28/28 [==============================] - 1s 22ms/step - loss: 1.3988e-04 - mean_absolute_error: 0.0084 - val_loss: 0.0039 - val_mean_absolute_error: 0.0488
# Epoch 68/100
# 28/28 [==============================] - 1s 22ms/step - loss: 1.3719e-04 - mean_absolute_error: 0.0085 - val_loss: 0.0034 - val_mean_absolute_error: 0.0451
# Epoch 69/100
# 28/28 [==============================] - 1s 22ms/step - loss: 1.5623e-04 - mean_absolute_error: 0.0092 - val_loss: 0.0059 - val_mean_absolute_error: 0.0633
# Epoch 70/100
# 28/28 [==============================] - 1s 22ms/step - loss: 1.2584e-04 - mean_absolute_error: 0.0082 - val_loss: 0.0032 - val_mean_absolute_error: 0.0440
# Epoch 71/100
# 28/28 [==============================] - 1s 22ms/step - loss: 1.3697e-04 - mean_absolute_error: 0.0086 - val_loss: 0.0026 - val_mean_absolute_error: 0.0384
# Epoch 72/100
# 28/28 [==============================] - 1s 22ms/step - loss: 1.3334e-04 - mean_absolute_error: 0.0085 - val_loss: 0.0044 - val_mean_absolute_error: 0.0540
# Epoch 73/100
# 28/28 [==============================] - 1s 22ms/step - loss: 1.4135e-04 - mean_absolute_error: 0.0088 - val_loss: 0.0046 - val_mean_absolute_error: 0.0557
# Epoch 74/100
# 28/28 [==============================] - 1s 22ms/step - loss: 1.1978e-04 - mean_absolute_error: 0.0079 - val_loss: 0.0024 - val_mean_absolute_error: 0.0375
# Epoch 75/100
# 28/28 [==============================] - 1s 22ms/step - loss: 1.2895e-04 - mean_absolute_error: 0.0081 - val_loss: 0.0025 - val_mean_absolute_error: 0.0382
# Epoch 76/100
# 28/28 [==============================] - 1s 22ms/step - loss: 1.2637e-04 - mean_absolute_error: 0.0081 - val_loss: 0.0023 - val_mean_absolute_error: 0.0359
# Epoch 77/100
# 28/28 [==============================] - 1s 22ms/step - loss: 1.2108e-04 - mean_absolute_error: 0.0080 - val_loss: 0.0020 - val_mean_absolute_error: 0.0332
# Epoch 78/100
# 28/28 [==============================] - 1s 22ms/step - loss: 1.2304e-04 - mean_absolute_error: 0.0078 - val_loss: 0.0045 - val_mean_absolute_error: 0.0541
# Epoch 79/100
# 28/28 [==============================] - 1s 22ms/step - loss: 1.2407e-04 - mean_absolute_error: 0.0079 - val_loss: 0.0025 - val_mean_absolute_error: 0.0382
# Epoch 80/100
# 28/28 [==============================] - 1s 22ms/step - loss: 1.1714e-04 - mean_absolute_error: 0.0077 - val_loss: 0.0029 - val_mean_absolute_error: 0.0424
# Epoch 81/100
# 28/28 [==============================] - 1s 22ms/step - loss: 1.0986e-04 - mean_absolute_error: 0.0075 - val_loss: 0.0019 - val_mean_absolute_error: 0.0331
# Epoch 82/100
# 28/28 [==============================] - 1s 22ms/step - loss: 1.1669e-04 - mean_absolute_error: 0.0077 - val_loss: 0.0048 - val_mean_absolute_error: 0.0562
# Epoch 83/100
# 28/28 [==============================] - 1s 22ms/step - loss: 1.2071e-04 - mean_absolute_error: 0.0080 - val_loss: 0.0032 - val_mean_absolute_error: 0.0451
# Epoch 84/100
# 28/28 [==============================] - 1s 22ms/step - loss: 1.2236e-04 - mean_absolute_error: 0.0079 - val_loss: 0.0038 - val_mean_absolute_error: 0.0497
# Epoch 85/100
# 28/28 [==============================] - 1s 22ms/step - loss: 1.3051e-04 - mean_absolute_error: 0.0085 - val_loss: 0.0019 - val_mean_absolute_error: 0.0337
# Epoch 86/100
# 28/28 [==============================] - 1s 22ms/step - loss: 1.1994e-04 - mean_absolute_error: 0.0080 - val_loss: 0.0017 - val_mean_absolute_error: 0.0310
# Epoch 87/100
# 28/28 [==============================] - 1s 22ms/step - loss: 1.1820e-04 - mean_absolute_error: 0.0079 - val_loss: 0.0025 - val_mean_absolute_error: 0.0393
# Epoch 88/100
# 28/28 [==============================] - 1s 22ms/step - loss: 1.1844e-04 - mean_absolute_error: 0.0079 - val_loss: 0.0021 - val_mean_absolute_error: 0.0351
# Epoch 89/100
# 28/28 [==============================] - 1s 22ms/step - loss: 1.0804e-04 - mean_absolute_error: 0.0074 - val_loss: 0.0020 - val_mean_absolute_error: 0.0347
# Epoch 90/100
# 28/28 [==============================] - 1s 22ms/step - loss: 1.1450e-04 - mean_absolute_error: 0.0077 - val_loss: 0.0024 - val_mean_absolute_error: 0.0390
# Epoch 91/100
# 28/28 [==============================] - 1s 22ms/step - loss: 1.0028e-04 - mean_absolute_error: 0.0070 - val_loss: 0.0020 - val_mean_absolute_error: 0.0337
# Epoch 92/100
# 28/28 [==============================] - 1s 22ms/step - loss: 1.0579e-04 - mean_absolute_error: 0.0073 - val_loss: 0.0019 - val_mean_absolute_error: 0.0335
# Epoch 93/100
# 28/28 [==============================] - 1s 23ms/step - loss: 1.0984e-04 - mean_absolute_error: 0.0074 - val_loss: 0.0029 - val_mean_absolute_error: 0.0445
# Epoch 94/100
# 28/28 [==============================] - 1s 22ms/step - loss: 1.1101e-04 - mean_absolute_error: 0.0077 - val_loss: 0.0022 - val_mean_absolute_error: 0.0370
# Epoch 95/100
# 28/28 [==============================] - 1s 23ms/step - loss: 1.0684e-04 - mean_absolute_error: 0.0071 - val_loss: 0.0024 - val_mean_absolute_error: 0.0390
# Epoch 96/100
# 28/28 [==============================] - 1s 23ms/step - loss: 1.1426e-04 - mean_absolute_error: 0.0076 - val_loss: 0.0013 - val_mean_absolute_error: 0.0264
# Epoch 97/100
# 28/28 [==============================] - 1s 23ms/step - loss: 9.9433e-05 - mean_absolute_error: 0.0071 - val_loss: 0.0030 - val_mean_absolute_error: 0.0451
# Epoch 98/100
# 28/28 [==============================] - 1s 23ms/step - loss: 1.0249e-04 - mean_absolute_error: 0.0070 - val_loss: 0.0021 - val_mean_absolute_error: 0.0362
# Epoch 99/100
# 28/28 [==============================] - 1s 23ms/step - loss: 9.7284e-05 - mean_absolute_error: 0.0070 - val_loss: 0.0022 - val_mean_absolute_error: 0.0368
# Epoch 100/100
# 28/28 [==============================] - 1s 22ms/step - loss: 1.1847e-04 - mean_absolute_error: 0.0078 - val_loss: 0.0027 - val_mean_absolute_error: 0.0418

# %%
# predicting the values after running the model
test_predicted = model.predict(test_seq)
test_predicted[:5]
# Out:
# 9/9 [==============================] - 1s 7ms/step
# array([[0.4009781 , 0.39791748],
#        [0.40054685, 0.39778033],
#        [0.39749146, 0.39499703],
#        [0.40202242, 0.3990669 ],
#        [0.40562916, 0.40245682]], dtype=float32)

# %%
# Inversing normalization/scaling on predicted data 
test_inverse_predicted = mms.inverse_transform(test_predicted)
test_inverse_predicted[:5]
# Out:
# array([[1414.3813, 1405.7363],
#        [1413.5818, 1405.4822],
#        [1407.9174, 1400.3237],
#        [1416.3174, 1407.8666],
#        [1423.004 , 1414.1494]], dtype=float32)

# %% [markdown]
# ### PREDICTED DATA VS VISUALIZING ACTUAL

# %%
# Merging actual and predicted data for better visualization
df_merge = pd.concat([df.iloc[-264:].copy(),
                          pd.DataFrame(test_inverse_predicted,columns=['open_predicted','close_predicted'],
                                       index=df.iloc[-264:].index)], axis=1)

# %%
# Inversing normalization/scaling 
df_merge[['open','close']] = mms.inverse_transform(df_merge[['open','close']])
df_merge.head()
# Out:
#                open    close  open_predicted  close_predicted
# date
# 2020-05-27  1417.25  1417.84     1414.381348      1405.736328
# 2020-05-28  1396.86  1416.73     1413.581787      1405.482178
# 2020-05-29  1416.94  1428.92     1407.917358      1400.323730
# 2020-06-01  1418.39  1431.82     1416.317383      1407.866577
# 2020-06-02  1430.55  1439.22     1423.004028      1414.149414

# %%
# plotting the actual open and predicted open prices on date index
df_merge[['open','open_predicted']].plot(figsize=(10,6))
plt.xticks(rotation=45)
plt.xlabel('Date',size=15)
plt.ylabel('Stock Price',size=15)
plt.title('Actual vs Predicted for open price',size=15)
plt.show()

# %%
# plotting the actual close and predicted close prices on date index 
df_merge[['close','close_predicted']].plot(figsize=(10,6))
plt.xticks(rotation=45)
plt.xlabel('Date',size=15)
plt.ylabel('Stock Price',size=15)
plt.title('Actual vs Predicted for close price',size=15)
plt.show()

# %% [markdown]
# ### PREDICTING UPCOMING 10 DAYS

# %%
# Creating a dataframe and adding 10 days to existing index 

df_merge = df_merge.append(pd.DataFrame(columns=df_merge.columns,
                                        index=pd.date_range(start=df_merge.index[-1], periods=11, freq='D', closed='right')))
df_merge['2021-06-09':'2021-06-16']
# Out:
#                open    close  open_predicted  close_predicted
# 2021-06-09  2499.50  2491.40     2346.817871      2283.711426
# 2021-06-10  2494.01  2521.60     2352.575928      2290.069092
# 2021-06-11  2524.92  2513.93     2369.620605      2304.991699
# 2021-06-12      NaN      NaN             NaN              NaN
# 2021-06-13      NaN      NaN             NaN              NaN
# 2021-06-14      NaN      NaN             NaN              NaN
# 2021-06-15      NaN      NaN             NaN              NaN
# 2021-06-16      NaN      NaN             NaN              NaN

# %%
# creating a DataFrame and filling values of open and close column
upcoming_prediction = pd.DataFrame(columns=['open','close'],index=df_merge.index)
upcoming_prediction.index=pd.to_datetime(upcoming_prediction.index)

# %%
curr_seq = test_seq[-1:]

for i in range(-10,0):
  up_pred = model.predict(curr_seq)
  upcoming_prediction.iloc[i] = up_pred
  curr_seq = np.append(curr_seq[0][1:],up_pred,axis=0)
  curr_seq = curr_seq.reshape(test_seq[-1:].shape)
# Out:
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step

# %%
# inversing Normalization/scaling
upcoming_prediction[['open','close']] = mms.inverse_transform(upcoming_prediction[['open','close']])

# %%
# plotting Upcoming Open price on date index
fig,ax=plt.subplots(figsize=(10,5))
ax.plot(df_merge.loc['2021-04-01':,'open'],label='Current Open Price')
ax.plot(upcoming_prediction.loc['2021-04-01':,'open'],label='Upcoming Open Price')
plt.setp(ax.xaxis.get_majorticklabels(), rotation=45)
ax.set_xlabel('Date',size=15)
ax.set_ylabel('Stock Price',size=15)
ax.set_title('Upcoming Open price prediction',size=15)
ax.legend()
fig.show()

# %%
# plotting Upcoming Close price on date index
fig,ax=plt.subplots(figsize=(10,5))
ax.plot(df_merge.loc['2021-04-01':,'close'],label='Current close Price')
ax.plot(upcoming_prediction.loc['2021-04-01':,'close'],label='Upcoming close Price')
plt.setp(ax.xaxis.get_majorticklabels(), rotation=45)
ax.set_xlabel('Date',size=15)
ax.set_ylabel('Stock Price',size=15)
ax.set_title('Upcoming close price prediction',size=15)
ax.legend()
fig.show()

# %% [markdown]
# You can find the project on <a href="https://github.com/Vyas-Rishabh/Stock_Price_Prediction_Using_LSTM"><b>GitHub.</b></a>
